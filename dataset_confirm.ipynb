# %%
import json
import numpy as np
from dbnet.dataset.tfrecord import gen_tfr, split,parse
import matplotlib.pyplot as plt
import cv2

# %%
with open("./save_500_int.json") as f:
    labels = json.load(f)["_via_img_metadata"]    
    
np.random.seed(42)
ds = list(labels.values())
np.random.shuffle(ds)

# %%
v

# %%
for i,x in enumerate(labels):
    v = labels[x]
    print(v['filename'])
    data = parse(v,folder="/datasets/almex_insurance/img/")
    imshow(data['img'])
    print(data['img'].shape)
#     print(data['img'].shape[0],data['img'].shape[1])
#     print(data['rs_h'],data['rs_w'])
#     cv2.imwrite('./threshold_map/'+data['filename'],data['threshold_map']*255)
#     cv2.imwrite('./threshold_mask/'+data['filename'],data['threshold_mask']*255)
#     cv2.imwrite('./shrink_map/'+data['filename'],data['shrink_map']*255)
    imshow(data['threshold_map'])
    print(data['threshold_map'].shape)
    imshow(data['threshold_mask'])
    imshow(data['shrink_map'])
    imshow(data['shrink_mask'])
    if i == 5:
        break
# Out:
# 554.jpg
# (736, 1120, 3)
# (736, 1120)
# 553.jpg
# (736, 1152, 3)
# (736, 1152)
# 552.jpg
# (736, 1184, 3)
# (736, 1184)
# 551.jpg
# (736, 1184, 3)
# (736, 1184)
# 550.jpg
# (736, 1152, 3)
# (736, 1152)
# 549.jpg
# (736, 1184, 3)
# (736, 1184)

# %%
data = parse(v,folder="/datasets/almex_insurance/img/")

# %%
data.keys()

# %%
def imshow(img):
    plt.imshow(img)
    plt.show()

# %%
import matplotlib.pyplot as plt
imshow(data['img'])
print(data['img'].shape[0],data['img'].shape[1])
print(data['rs_h'],data['rs_w'])
imshow(data['threshold_map'])
imshow(data['threshold_mask'])
imshow(data['shrink_map'])
imshow(data['shrink_mask'])

# %%
imshow(cv2.imread('./threshold_map/544.jpg'))

# %%
data['threshold_map']

# %%
from dbnet.dataset import TFRecordLoader

# %%
tfloader = TFRecordLoader()

# %%
import tensorflow as tf

# %%
data = tfloader.get_ds_from('./conf/lin_train.yaml')

# %%
data

# %%
for d in data.take(5):
    print('prob')
    plt.imshow(d[1]['prob'].numpy()[0,...,0]/255)
    plt.show()
#     print(d[1]['binary'].numpy().shape)
    print('binary')
    plt.imshow(d[1]['binary'].numpy()[0,...,0]/255)
    plt.show()
